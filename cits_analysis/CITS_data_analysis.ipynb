# %% [markdown]
# # Import deps

# %% [markdown]
# Download stmpy
#
# ! pip install hoffmanstmpy
#
# source: https://github.com/hoffmanlabcoding/stmpy/tree/main

# %%
from CITS_Class import CITS_Analysis
import  numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Implementation

# %% [markdown]
# ## Define object

# %%
data = CITS_Analysis('cits_data.3ds')

#Meta data 
data.header
# Out:
# File import successful.
# WARNING: Using scan channel for Z attribute.
# WARNING: Assuming energy layers are evenly spaced.
# {'Grid dim': '"250 x 80"',
#  'Grid settings': '-8.998863E-7;-2.859467E-8;2.500000E-7;2.500000E-7;-6.000000E+1',
#  'Filetype': 'Linear',
#  'Sweep Signal': '"Bias (V)"',
#  'Fixed parameters': '"Sweep Start;Sweep End"',
#  'Experiment parameters': '"X (m);Y (m);Z (m);Z offset (m);Settling time (s);Integration time (s);Z-Ctrl hold;Final Z (m)"',
#  '# Parameters (4 byte)': '10',
#  'Experiment size (bytes)': '1452',
#  'Points': '121',
#  'Channels': '"Current (A);LIX 1 omega (A);LIY 1 omega (A)"',
#  'Delay before measuring (s)': '10.000000E-3',
#  'Experiment': '"Grid Spectroscopy"',
#  'Start time': '"03.11.2023 17:47:12"',
#  'End time': '"04.11.2023 08:23:48"',
#  'User': '',
#  'Comment': '',
#  'Bias>Bias (V)': '-1.5E+0',
#  'Bias>Calibration (V/V)': '1E+0',
#  'Bias>Offset (V)': '0E+0',
#  'Bias Spectroscopy>Sweep Start (V)': '-1.5E+0',
#  'Bias Spectroscopy>Sweep End (V)': '1.5E+0',
#  'Bias Spectroscopy>Num Pixel': '121',
#  'Bias Spectroscopy>Z Avg time (s)': '50E-3',
#  'Bias Spectroscopy>Z offset (m)': '0E+0',
#  'Bias Spectroscopy>1st Settling time (s)': '5E-3',
#  'Bias Spectroscopy>Settling time (s)': '4E-3',
#  'Bias Spectroscopy>Integration time (s)': '10E-3',
#  'Bias Spectroscopy>End Settling time (s)': '5E-3',
#  'Bias Spectroscopy>Z control time (s)': '50E-3',
#  'Bias Spectroscopy>Max Slew rate (V/s)': '10E+0',
#  'Bias Spectroscopy>backward sweep': 'FALSE',
#  'Bias Spectroscopy>Z-controller hold': 'TRUE',
#  'Bias Spectroscopy>Number of sweeps': '1',
#  'Bias Spectroscopy>Channels': '"Current (A);LIX 1 omega (A);LIY 1 omega (A)"',
#  'Bias Spectroscopy>Reset Bias': 'TRUE',
#  'Bias Spectroscopy>Record final Z': 'FALSE',
#  'Bias Spectroscopy>Lock-In run': 'TRUE',
#  'Bias Spectroscopy>Sweep mode': 'Linear',
#  'Bias Spectroscopy>MultiLine Settings : Segment Start (V), Segment End (V), Settling (s), Integration (s), Steps (xn)': '-1E+0,1E+0,100E-6,100E-6,256',
#  'Lock-in>Lock-in status': 'ON',
#  'Lock-in>Modulated signal': '"Bias (V)"',
#  'Lock-in>Frequency (Hz)': '977.1E+0',
#  'Lock-in>Amplitude': '20E-3',
#  'Lock-in>Demodulated signal': '"Current (A)"',
#  'Lock-in>Harmonic': '2',
#  'Lock-in>Reference phase (deg)': '-193.331E+0',
#  'Z-Controller>Z (m)': '76.0529E-9',
#  'Z-Controller>Controller name': '"log Current"',
#  'Z-Controller>Controller status': 'ON',
#  'Z-Controller>Setpoint': '200E-12',
#  'Z-Controller>Setpoint unit': 'A',
#  'Z-Controller>P gain': '27.265E-12',
#  'Z-Controller>I gain': '87.822E-9',
#  'Z-Controller>Time const (s)': '310.457E-6',
#  'Z-Controller>TipLift (m)': '0E+0',
#  'Z-Controller>Switch off delay (s)': '50E-3'}

# %% [markdown]
# ## CITS attributes:

# %%
# Frame size
frame_size = data.get_frame_size()
print('frame_size = ', frame_size)

#Grid size of CITS:
grid_size =  data.data_size
print('\ngrid_size = ',grid_size)
# Out:
# frame_size =  (2.5e-07, 2.5e-07)
#
# grid_size =  "250 x 80"

# %% [markdown]
# ## Spectral Analysis

# %%
#Bias sweep range

V_range =  data.V_range



# Current Hyper-Spectral data
i = data.current
didv = data.didv_x
print(i.shape)



#Use position index on the hyperspectral data
i = i[0, 0]
didv = didv[0,0]
v = V_range

fig, ax = plt.subplots(1, 2, figsize = (10, 4))
ax[0].plot(v, i, label = "current")
ax[0].legend
ax[1].plot(v, didv, label = "didv")
ax[1].legend()
# Out:
# (80, 250, 121)

# %% [markdown]
# Use position (in nm) to get the closest data

# %%
probe_point = [2E-7, 2E-7]

point, point_index = data.nearest_point(probe_point)

print(point, point_index)

#Current 
 
i =  data.current[point_index[0], point_index[1]]
didv_x = data.didv_x[point_index[0], point_index[1]]
v = data.V_range

fig, ax = plt.subplots(1, 2, figsize = (10, 4))
ax[0].plot(v, i, label = "current")
ax[0].legend
ax[1].plot(v, didv, label = "didv")
ax[1].legend()
# Out:
# [1.9936708860759493e-07, 1.9979919678714856e-07] [63, 199]

# %% [markdown]
# ## Get CITS maps

# %% [markdown]
# ### Current maps

# %%
fig = plt.plot(figsize=(7, 10))

probe_bias = 1.2
i_2D, V_actual = data.current_map(probe_bias)
print('Nearest Probed bias = ',V_actual)




plt.imshow(i_2D, origin = 'lower')

plt.show()
# Out:
# Nearest Probed bias =  1.2000000000000002

# %% [markdown]
# ### didv maps

# %%
fig = plt.figure(figsize=(10, 10))

probe_bias = 1.2
i_2D, V_actual = data.didv_x_map(probe_bias)
print('Nearest Probed bias = ',V_actual)

plt.imshow(i_2D, origin = 'lower')
plt.show()
# Out:
# Nearest Probed bias =  1.2000000000000002
